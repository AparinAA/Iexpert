# %%
# JSON I EXPERT 2020 (комментарии к форме оценок)
import json

dict_ = {
"common":
    {
        "score": """ <p><small class='text-muted'>Указание:  <i> проводится экспертиза Формы №5 (Сведения о возможности образовательной организации и партнеров направления по продвижению Олимпиады) и остальных документов заявки </i></p>
        Данный критерий оценивает:
        <ul>
        <li>потенциал информационной активности образовательного учреждения, готовность инфраструктуры для продвижения заявленного направления и олимпиады «Я – профессионал» в целом;</li>
        <li>авторитет вуза в заявленной сфере;</li>
        <li>привлекательность предлагаемого направления олимпиады для участия студентов разных направлений и специальностей;</li>
        <li>соответствие возможностей вуза проведению заявленного направления с учетом принципа географического равенства.</li>
        </ul></small>""",
        "comment":  """<small class="text-muted">Оставьте общий комментарий по заявке (не более 1000 символов)</small>"""
    },
"expert":
    {
        "score1": """
            <small class="text-muted">Указание: <i> проводится экспертиза Справки о содержании контрольно-измерительных материалов направления </i>
            <p> Данный критерий оценивает творческий характер, уровень сложности и новизну демоверсий заданий, их направленность на выявление интеллектуального потенциала, аналитических способностей и креативности мышления участников.</p>
            Данный критерий оценивает также наличие и содержание спецификаций заданий и дополнительных методических материалов.</small>""",
        "score2": """
            <small class="text-muted">Указание: <i> проводится экспертиза Справки о содержании контрольно-измерительных материалов направления и Справки об организационно-методическом сопровождении направления олимпиады</i>
            <p> Данный критерий оценивает наличие практико-ориентированной составляющей в заданиях, направленность формата проведения на выявление практических навыков и профессионального потенциала участников, а также вовлеченность партнеров-работодателей в реализацию направления</p> </small>""",
        "score3": """
            <small class="text-muted">Указание: <i>проводится экспертиза Справки об организационно-методическом сопровождении направления олимпиады </i>
            <p> Данный критерий оценивает уровень профессиональной квалификации членов оргкомитета олимпиады, методической комиссии и жюри, а также наличие среди членов представителей партнёров-работодателей направления </p></small>
        """,
        "score4": """
            <small class="text-muted">Указание: <i>проводится экспертиза Справки об образовательной организации высшего образования в контексте олимпиады </i>
            <p> Данный критерий оценивает организационный опыт, в том числе опыт проведения Всероссийской олимпиады студентов «Я-профессионал», а также степень соответствия направления профилю образовательной организации</p></small>
        """,
        "score5": """
            <small class="text-muted">Указание: <i> проводится экспертиза Общих сведений об образовательной организации высшего образования в контексте олимпиады </i>
            <p>Данный критерий оценивает развитость и доступность инфраструктуры для предлагаемого формата организации и проведения очного этапа олимпиады соответствующего направления </p></small>
        """,
        "comment":  """<small class="text-muted">Оставьте общий комментарий по заявке (не более 1000 символов)</small>"""
    }
}

# %%
with open('info.json', 'w', encoding='utf-8') as outfile:
    json.dump(dict_, outfile)
    
with open('info.json', 'r', encoding='utf-8') as file:
    data_score = json.load(file)

# %%
data_score['expert']['comment']
# Out:
# 'Оставьте общий комментарий по заявке (не более 1000 символов)'

# %%
with open('info.json', 'w', encoding='utf-8') as outfile:
    json.dump(dict_, outfile)

# %%
data_score
# Out:
# {'common': {'score': ' Указание!:  <h2> проводится экспертиза Формы №5 (Сведения о возможности образовательной организации и партнеров направления по продвижению Олимпиады) и остальных документов заявки </h2>\n\n        <p> Данный критерий оценивает: </p>\n\n        <ul>\n\n        <li>потенциал информационной активности образовательного учреждения, готовность инфраструктуры для продвижения заявленного направления и олимпиады «Я – профессионал» в целом;</li>\n\n        <li>авторитет вуза в заявленной сфере;</li>\n\n        <li>привлекательность предлагаемого направления олимпиады для участия студентов разных направлений и специальностей;</li>\n\n        <li>соответствие возможностей вуза проведению заявленного направления с учетом принципа географического равенства.</li>\n\n        </ul>\n',
#   'comment': 'Оставьте общий комментарий по заявке (не более 1000 символов)\n'},
# ...
